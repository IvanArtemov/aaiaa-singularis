# %%
# !pip install PyMuPDF
# !pip install spacy

# %%
import re

import fitz  # PyMuPDF for PDF parsing
import spacy

# %%
# !python -m spacy download en_core_web_sm

# %%
def parse_pdf(path):
    fitzed_doc = fitz.open(path)
    text = ""
    for page in fitzed_doc:
        text += page.get_text()
    return text

# %%
nlp = spacy.load("en_core_web_sm")
paper = r"Papers/scitranslmed.adi0673 annotated.pdf"  # Path to the PDF file

# %%
raw_text = parse_pdf(paper)
doc = nlp(raw_text)

# %%
hypothesis_patterns = (
    r"(hypothesis|H\d+)[:–-]",
    r"(theor(ies|y)|hypothes[ei]s) (is|was|are|were|that)",
    r"(we|I|authors?|it is|study|theor(ies|y)|hypothes[ei]s) (hypothesi[sz]e|predict|propose|assume|expect|anticipate|foresee|postulate|conjecture|test|suggest)",
    r"(hypothesi[sz]e|predict|propose|assume|expect|anticipate|foresee|postulate|aim|conjecture|test|suggest)(s|d)? that"
    r"(investigate|examine|predict|test)(s|d)? (whether|if)",
    r"(evidence|data) (predict|suggest|propose|assume)"
    r"(aim|objective|goal) (of th(is|e) study)",
    r"if.*then",
    r"it would appear",
    r"it likely that",
    r"According to the (theor(ies|y)|hypothes[ei]s|views?)"
)

methods_patterns = (
    r"(methods?|methodology|procedures?|techniques?) (is|was|are|were|that|[:–-])",
    r"(we|I|authors?|the study) (used|employed|applied|conducted|performed|carried out|implemented)",
    r"(data (collection|gathering|acquisition)|samples?|participants?|subjects?) (were|was)",
    r"(measurements?|assays?|tests?|analyses?) (were|was) (performed|conducted|carried out|done)",
    r"(statistical|analysis|analytical) (methods?|approach|procedure)",
    r"(in order to (determine|measure|assess|evaluate|test|quantify))",
    r"(equipment|instruments?|software|apparatus|tools?) (was|were|used)",
    r"(protocol|procedure|experimental design) (was|were)",
    r"(collection period|duration|timeframe) (was|of)",
    r"(participants?|subjects?|samples?) (were |was )?(recruited|selected|enrolled|obtained)",
    r"(inclusion|exclusion) (criteria|requirements)",
    r"(we|I|authors?) (measure|perform|conduct|test|quantif(y|ied)|employ|adopt)",
    r"(was|were) (stained|embedded|measured|performed|calculated|obtained|identified|detected|monitored|isolated|stimulated|used|removed|harvested|acqired|gated|tested|considered)",
    r"(regression|ANOVA|t-test|chi-square|Wilcoxon|Mann-Whitney|Kruskal-Wallis|Fisher['’]s (exact)?) (test|analysis|model)",
    r"(correlation|association|relationship) (was|were) (assessed|examined|evaluated|tested)",
    r"(clustering|classification|regression|neural network|deep learning|random forest|support vector) (was|were) (performed|applied|used)",
    r"(principal component analysis|PCA|factor analysis|dimensionality reduction) (was|were) (performed|conducted)",
    r"(R|Python|MATLAB|SPSS|SAS|Stata|GraphPad|TensorFlow|PyTorch|scikit-learn) (was|were) used",
    r"(software|tool|package|library) (was|were) used",
    r"(cross-validation|bootstrapping|permutation test) (was|were) (performed|conducted|used)",
)

dataset_patterns = (
    r"(dataset|data set|database|data source|repository) (was|were|is|are|used|obtained|available|collected|generated|produced)",
    r"(available|accessible|open) (dataset|data set|database|data source|repository)",
    r"(downloaded|retrieved|obtained|accessed) from (the )?(database|repository|server|(web)?site|portal)",
    r"data( were)? (obtained|retrieved|downloaded|sourced)",
    r"(doi|accession number|repository|github|zenodo|figshare|osf|dryad)\s*[:–-]",
    r"(supplementary )?data (available )?(at|in|from|on)",
    r"(gene expression|genomic|proteomic|metabolomic|imaging) dataset",
    r"(data (necessary )?to reproduce|reproducib(le|ility))",
    r"(accession|catalog) (number|code)\s*[:–-]",
    r"(data|dataset) (was|were) (normalized|standardized|preprocessed|filtered|transformed|cleaned)",
    r"(normalized|standardized|preprocessed|filtered|transformed|cleaned) (the )?(data|dataset)",
)

experiment_patterns = (
    r"(experiment|assay|trial|test)\s*(\d+|[A-Z])?(\s*[:–-])",
    r"(test|examine|investigate|evaluate|assess|determine|measure) (the )?(hypothesis|prediction|effect|impact|role|function)",
    r"(performed|conducted|carried out|designed|set up) (an? )?(experiment|assay|trial|test|study)",
    r"experimental (design|setup|procedure|protocol|approach)",
    r"(treatment|condition|group) (was|were)( exposed| treated)",
    r"(control|experimental|treatment) group",
    r"(exposed|subjected|treated|stimulated|challenged) (to|with)",
    r"(intervention|treatment|manipulation) (was|were)",
    r"(validation|confirmatory|confirmation) (experiment|assay|test)",
    r"(parallel|sequential|longitudinal) (experiment|test|measurement)",
)

analysis_patterns = (
    r"(analysis|analyses) (was|were|performed|conducted)",
    r"(p-value(s)?|statistical significance) (was|were) (calculated|assessed|determined)",
    r"(supervised|unsupervised) (learning|modeling|analysis) (was|were)",
    r"(accuracy|precision|recall|F1 score|AUC|ROC curve) (was|were|are|is)",
    r"(we|I|authors?) (evaluated|assessed|validated) (the )?(model|results|performance|hypothesis)",
    r"(data|results) (was|were) (visualized|plotted|presented|graphed) (using|with|as)",
)

result_patterns = (
    r"(we|I|authors?) (analyzed|assessed|evaluated|quantified|examined|compared) (the )?(data|results|effects)",
    r"(results?|findings?|outcomes?|data|evidence|analysis) (show|demonstrate|indicate|reveal|suggest|support|imply|point|provide|confirm|validate)",
    r"(we|I|authors?|the study) (found|observed|noted|reported|detected|identified|demonstrate|confirm|establish|conclude|infer)",
    r"((no )?significant|(not )?statistically significant) (effect|difference|correlation|association|relationship) (was|were) (found|observed|detected)",
    r"(p (<|>|<=|>=|=) \d*\.?\d+| p-value(s)? (of|less than|greater than))",
    r"(higher|lower|greater|smaller|increased|decreased|stronger|weaker) (than|compared to|relative to)",
    r"(positive|negative|significant|weak|strong) (correlation|association|relationship) (was|were) (found|observed|detected)",
    r"(trend(s)?|pattern(s)?) (was|were) (observed|noted|evident|apparent)",
    r"(model|algorithm) (achieved|obtained|yielded|produced) (an? )?(accuracy|precision|recall|F1 score|AUC)",
    r"(effect|impact|influence|role) (of \w+ on \w+) (was|were) (observed|found|significant|notable)",
)

compiled_hypothesis_patterns = [re.compile(p, re.IGNORECASE) for p in hypothesis_patterns]
compiled_methods_patterns = [re.compile(p, re.IGNORECASE) for p in methods_patterns]
compiled_dataset_patterns = [re.compile(p, re.IGNORECASE) for p in dataset_patterns]
compiled_experiment_patterns = [re.compile(p, re.IGNORECASE) for p in experiment_patterns]
compiled_analysis_patterns = [re.compile(p, re.IGNORECASE) for p in analysis_patterns]
compiled_result_patterns = [re.compile(p, re.IGNORECASE) for p in result_patterns]

# %%
hypotheses = []
methods = []
datasets = []
experiments = []
analyses = []
results = []
for ind, sent in enumerate(doc.sents):
    sent_text = re.sub(r'\s+', ' ', sent.text.strip().replace("\n", " "))
    if sent_text and any(pattern.search(sent_text) for pattern in compiled_hypothesis_patterns):
        hypotheses.append(sent_text)
    elif sent_text and any(pattern.search(sent_text) for pattern in compiled_methods_patterns):
        methods.append(sent_text)
    elif sent_text and any(pattern.search(sent_text) for pattern in compiled_dataset_patterns):
        datasets.append(sent_text)
    elif sent_text and any(pattern.search(sent_text) for pattern in compiled_experiment_patterns):
        experiments.append(sent_text)
    elif sent_text and any(pattern.search(sent_text) for pattern in compiled_analysis_patterns):
        analyses.append(sent_text)
    elif sent_text and any(pattern.search(sent_text) for pattern in compiled_result_patterns):
        results.append(sent_text)

hypotheses, methods, datasets, experiments, analyses, results
# Out:
# (['We hypothesized that the existence of high-\xadaffinity peanut-\xadspecific IgG+ memory B cells and their abil- ity to undergo class switching to IgE are critical for allergy persistence in pediatric peanut allergy.',
#   'In line with our model of IgE cell differentiation developed from mouse studies (2, 3, 7, 43), we proposed that allergen-\xadspecific IgG+ memory B cells ex- pressing CD23/FCER2 and germline IGHE are precursors of patho- genic IgE+ plasma cells in highly sensitized peanut-\xadallergic individuals.',
#   'We propose that CD23+IGHE+IgG1+ memory B cells are involved in the persistence of food allergy by providing precursors of pathogenic IgE plasma cells.',
#   'We hypothesized that IgG1+ memory B cells are the precursors of high-\xadaffinity, pathogenic IgE+ plasma cells in persistent peanut allergy.',
#   '10X Genomics scRNA-\xadseq processing and analysis 10X Genomics 5′ scRNA-\xadseq data were processed with Cell Ranger version 3.1 and aligned to refdata-\xadcellranger-\xadGRCh38-\xad3.0.0.',
#   'We tested this in our data by quantifying the SHM frequency of IGHM heavy chain consensus sequences.',
#   'M. Descatoire, S. Weller, S. Irtan, S. Sarnacki, J. Feuillard, S. Storck, A. Guiochon-\xadMantel, J. Bouligand, A. Morali, J. Cohen, E. Jacquemin, M. Iascone, C. Bole-\xadFeysot, N. Cagnard, J. C. Weill, C. A. Reynaud, Identification of a human splenic marginal zone B cell precursor with NOTCH2-\xaddependent differentiation properties.'],
#  ['A corresponding population of “type 2–marked” IgG1+ memory B cells was identified in single-\xadcell RNA sequencing experiments.',
#   'CD27 was used as a marker of memory B cells that are somatically mutated and likely to contain allergen-\xadspecific clones (26).',
#   'A cluster of somatically mutated switched memory cells expresses FCER2, IL4R, and IGHE To further characterize B cell memory subsets, we performed 10X Genomics scRNA-\xadseq of whole transcriptomes and BCRs on flow-\xad sorted CD27+ memory B cells from five peanut-\xadallergic children with PsIgE>100 and three non-\xadallergic children (table S2).',
#   'To further understand the biological processes shaping the memory B cells in cluster 5, we performed a Gene Ontology (GO) enrich- ment analysis.',
#   'These conditions were op- timized for B cell proliferation and plasma cell differentiation and also allowed class switching to IgE. After 7 days, peanut-\xadspecific anti- bodies were measured in the culture supernatants, and cells were analyzed by flow cytometry.',
#   'In day 9 culture supernatants, peanut-\xadspecific IgG was detected in 93% of wells from CD23+IgG+ memory B cells but only in 12% of wells from CD23−IL-\xad4R+IgG+ memory B cells (Fig. 4C).',
#   'DT binders were detected at similar frequencies among the three groups (fig. S10B).',
#   'i c l e 6 of 14 (cluster 5; Fig. 2), we used real-\xadtime polymerase chain reaction (PCR) to quantify FCER2/CD23, germline IGHE (GLT-\xadIGHE), and total-\xad\u200bIGHE transcripts in all antigen-\xadbinding IgG1+ cells from peanut-\xadallergic individuals with PsIgE>100 and from non-\xadallergic individuals (Fig. 5C).',
#   'FCER2/CD23 expression was detected in most Ara h 2–binding IgG1+ cells from peanut-\xadallergic individuals, and its average expression was significantly higher in Ara h 2–binding IgG1+ cells than DT-\xadbinding IgG1+ cells from peanut-\xadallergic (P = 0.0028) or non-\xadallergic individuals (P = 0.0150).',
#   'Total-\xad\u200bIGHE and germline IGHE transcripts were detected in most Ara h 2–binding cells but few DT-\xadbinding cells.',
#   'High-\xadaffinity convergent Ara h 2–specific BCR sequences were identified across different individuals BCRs within individual humans are highly diverse, and identification of similar sequences among different individuals may be indicative of convergent antigen-\xaddriven selection.',
#   'To identify convergent BCRs specific for Ara h 2, we performed clustering on the basis of IGH amino acid sequence similarity using the BCR sequencing data from Ara h 2 and DT binders and from all memory B cells profiled in the 10X scRNA-\xadseq experiment.',
#   '(B) Culture supernatants of IgG+ memory B cells from non-\xadallergic individuals (N = 7, left), peanut-\xadallergic individuals with PsIgE<5 (N = 7, middle), and peanut-\xadallergic individuals with PsIgE>100 (N = 7, right) were tested for the reac- tivity against peanut by ELISA.',
#   '(C) Culture supernatants of IgG+ memory B cells from peanut-\xadallergic individuals with PsIgE>100 (N = 4) were tested for the reactivity of IgG against peanut (top) and Ara h 2 (bottom) by ELISA.',
#   'Al- though this was considered evidence of lower maturation of IgE+ cells, it could reflect a developmental relationship between IgE+ cells and their potential precursors, CD23+IgG1+ memory B cells.',
#   'The scRNA-\xadseq experiment was performed with a relatively small number of samples and did not provide enough power for group comparisons.',
#   'The analysis was performed with PBMC samples from blood collected between 2019 and 2023.',
#   'Blood samples that yielded more than 30 × 106 PBMCs were used for the study.',
#   'Thus, we performed a phe- notypic and transcriptional analysis of total memory B cells by flow cytometry and 10X Genomics (WTA and BCR) scRNA-\xadseq and characterized allergen-\xadspecific B cells by plate-\xadbased single-\xadB cell analysis of BCR sequence and selected genes’ expression.',
#   'Each experimental value was obtained from a unique sample, because only one blood sample was obtained from each donor.',
#   'Patient samples For flow cytometry and the initial cell culture studies, PBMCs were isolated from peripheral blood from 58 pediatric patients with peanut allergy and 13 non-\xadallergic children.',
#   'PsIgE concentrations obtained on the day of the blood draw were used to select the patients.',
#   'Four samples were obtained from PsIgE>100 pa- tients for the additional cell culture studies.',
#   '10X Genomics scRNA-\xadseq of memory B cells B cells were isolated from 17 million to 100 million PBMCs from five peanut-\xadallergic individuals with sIgE>100 and three non-\xadallergic individuals (table S2) by EasySep Human B cell Isolation Kit (STEM- CELL Technologies, #17954).',
#   'V, D, and J genes from the IGH, IGL, and IGK loci were removed so that the properties of the BCR expressed by the cell would remain independent of the cluster it was assigned to.',
#   'Integration was performed using the previously identified top variable genes of each run and the first 20 dimensions.',
#   'i c l e 11 of 14 identified as T cells and naïve B cells, which were removed.',
#   'To identify DEGs in each cluster, the FindAllMarkers function from Seurat was used.',
#   'P values were calculated using a Wilcoxon rank sum test and were adjusted using a Bonferroni adjustment.',
#   'To identify the enrichment of GOs for each cluster, the list of positive DEGs for each cluster was tested using enrichR v3.0 (58, 59).',
#   'Similarly, detoxified DT (CRM197, PFENEX Biopharmaceuticals) was used to generate DT multimers.',
#   'Pre-\xadenriched B cells by EasySep Human B cell Isolation Kit (STEMCELL Technologies, #17954) from eight peanut-\xadallergic individuals with PsIgE>100, five peanut-\xad allergic individuals with PsIgE<5, and two non-\xadallergic individuals were used for Ara h 2 binder or DT binder sorting (table S5).',
#   'Plates were thawed on ice, and then oligo dT was added and annealing was performed at 70°C for 5 min. cDNA synthesis and cDNA amplification were performed with template switching oligo (TSO) using template switching RT enzyme mix (NEB, #M0466) according to the manufacturer’s instruc- tion.',
#   'The first PCR was performed to amplify BCR heavy and light chains using outer primers targeting human immunoglobulin con- stant regions (IgG and IgM for heavy chains; kappa and lambda for light chains) and TSO inner primer (table S6), respectively.',
#   'All PCR reactions were performed using the NEBNext Ultra II Q5 master mix (NEB, #M0544).',
#   'B cell receptor sequence processing and analysis BCR sequencing was obtained from two sources: 10X Genomics scRNA-\xad seq + BCR sequencing and PacBio single-\xadcell BCR sequencing.',
#   'Nonproductive heavy and light chain BCR sequences were removed.',
#   'Further processing was performed using presto v0.6.2 (62).',
#   'To remove reads too short to likely contain functional BCRs and associated constant regions, reads shorter than 500 bp were removed.',
#   'Nucleotide sites matching primer sequences, as well as the sites downstream of them, were removed.',
#   'Sites in which >50% of reads contained gap characters were removed.',
#   'Read groups containing fewer than 10 reads or in which >10% of sites differed from their final consensus sequence were removed.',
#   'Nonproductive heavy and light chain BCR sequences were removed.',
#   'As a further quality control, 16 sequences originated from wells in which no Ig DNA was detected through PCR and were discarded.',
#   'For ambiguous V gene assignments, only the first assignment was used for reconstruction.',
#   'The Shapiro-\xadWilk test was performed to select either one-\xadway ANOVA or the Kruskal-\xadWallis test for the statistical significance for >2 groups.',
#   'Either the two-\xadsided Student’s t test or the two-\xadsided Mann-\xadWhitney U test was used to perform the parametric or nonparametric tests, respectively, for two-\xadgroup comparisons with a 95% confidential inter- val for the median.',
#   'For correlation analysis, the Shapiro-\xadWilk test was performed to select a nonparametric Spearman’s correlation test.',
#   'The chi-\xadsquare test was used to determine the significant differ- ences between expected frequencies and observed frequencies.'],
#  ['Data in (D) are presented as box and whiskers plots in which boxes represent the median as well as the first and third quartiles, and whiskers extend to the largest and smallest values within 1.5 times the interquartile range from the boxes.',
#   'We then used Seurat’s IntegrateData function to combine data from the three sequencing runs.',
#   'BCR sequence data from 10X Genomics scRNA-\xadseq + BCR sequencing began with the filtered V(D)J contigs from 10X Genomics Cell Ranger version 3.1.',
#   'For BCR sequencing data from sorted single-\xadcell PacBio sequencing data, adaptor ligation, sequencing reactions, and initial sequence processing were conducted at GENEWIZ, LLC/Azenta US Inc. using standard PacBio circular consensus sequence tools and guidelines.',
#   'For BCR data from both data sources, SHM frequencies were de- termined for each cell as the frequency of nonambiguous mismatch- es along the immunoglobulin heavy chain variable (IGHV) gene of the unmutated germline sequence along IMGT positions 1 to 312 using shazam v1.1.2 (65).',
#   'S1 to S13 Tables S1 to S7 Other Supplementary Material for this manuscript includes the following: Data files S1 to S4 MDAR Reproducibility Checklist REFERENCES AND NOTES 1. S. H. Sicherer, H. A. Sampson, Food allergy: A review and update on epidemiology, pathogenesis, diagnosis, prevention, and management.'],
#  ['L. conceptualized the study, and M.O. designed the experimental approach.'],
#  ['Our transcriptional analysis was done on CD27+ memory B cells, and it did not distinguish CD45 isoforms.'],
#  ['Our findings indicate that CD23+IgG1+ memory B cells transcribing germline IGHE are a unique memory population containing precur- sors of high-\xadaffinity pathogenic IgE-\xadproducing cells that are likely to be involved in the long-\xadterm persistence of peanut allergy.',
#   'Consistent with previous observations, we found a significantly (P < 0.001) higher percentage of CD23+ total, naïve, and memory B cells in peanut-\xad allergic than in non-\xadallergic children of a similar age range (Fig.',
#   'A significant correlation was found between to- tal IgE and CD23+IgM/IgD+ memory B cells (P = 0.004), CD23+ IgM/IgD− memory B cells (P < 0.001), and CD23+IgG+ memory B cells (P < 0.001) (Fig. 1B).',
#   'The concentrations of total IgE in circula- tion also correlated significantly (P < 0.001) with PsIgE and with IgE specific for the main peanut allergen, Ara h 2 (fig.',
#   'A significant (P < 0.001) difference in total IgE concentrations was observed between individuals with a very high concentration of PsIgE in the blood (PsIgE>100 kUA/liter referred to as PsIgE>100, n = 18) and those with PsIgE lower than 5 kUA/liter (referred to as PsIgE<5, n = 16), whereas total IgE concentrations varied among peanut-\xadallergic individuals with intermediate PsIgE (5 < PsIgE<100) (fig. S1B).',
#   'However, only the PsIgE>100 peanut-\xad allergic group had a significantly higher frequency of CD23+ IgM/ IgD− memory B cells (P < 0.001) and CD23+ IgG+ memory B cells (P = 0.002) (Fig. 1D and fig. S2D) without a significant (P > 0.05) increase in total IgG+ memory B cells (fig.',
#   'Although the frequency of CD23+ naïve B cells was similarly increased in peanut-\xadallergic individuals with very high or very low concentrations of PsIgE, only highly sensitized individuals had a significantly higher frequency of CD23+CD27+IgG+ memory B cells as percentage of total B cells or of CD27+ memory B cells compared with non-\xadallergic individuals (P = 0.0002 in Fig.',
#   '1D and P = 0.004 in fig. S3C).',
#   'We identified 10 clusters of memory B cells (numbered 0 to 9) and identified dif- ferentially expressed genes (DEGs) in each cluster (Fig. 2, A and B, figs.',
#   'We detected CD73/ NT5E expression in only a small percentage of cells in clusters 4, 5, and 6, and transcripts for FAS/CD95 and ITGAX/CD11c were undetect- able in most cells (fig. S7).',
#   'We found that cells from peanut-\xadallergic individuals in cluster 5 were enriched for cytokine-\xadmediated signaling pathway signatures (GO: 009221) (ta- ble S4).',
#   'Although true IgE cells were rare, we identified two B cells with IGHE BCRs, each from a different peanut-\xadallergic individual and both belonging to cluster 5 (fig. S8).',
#   'In the scRNA-\xadseq experiment, we identified 178 B cells with normalized IGHE transcript values at least as high as the two B cells found with IGHE BCRs (Fig. 3A).',
#   'Genes are positively DEGs (adjusted P < 0.05) for cluster 5.',
#   'Enrichment for IGHG-\xadassociated BCRs was ana- lyzed by chi-\xadsquare test (cluster 5: 61.7% of cells, P < 2.2 × 10−16).',
#   'Class switching to IgE was relatively low in these culture conditions; nevertheless, we detected the highest frequency of IgE+ B cells in the cultures of CD23+/IL-\xad4R+IgG+ memory B cells from peanut-\xadallergic children with high PsIgE (PsIgE>100) (fig. S9C).',
#   'Total IgE was significantly (P < 0.001) higher in supernatants from CD23+IgG+ memory B cells than in supernatants from CD23−IL-\xad4R+ (or CD23−IL-\xad4R−)',
#   'The frequency of Ara h 2–binding B cells was significantly (P = 0.02) higher in peanut-\xadallergic individuals with PsIgE>100 than in peanut-\xadallergic individuals with PsIgE<5, whereas Ara h 2 binders were undetectable in non-\xadallergic samples.',
#   'Heavy chain sequences of Ara h 2–binding IgG+ B cells from peanut-\xad allergic individuals were significantly (P < 0.001) more mutated than DT-\xadbinding IgG+ B cells from both peanut-\xadallergic and non-\xad allergic individuals (Fig. 5A).',
#   'Furthermore, Ara h 2–binding IgG+ B cells from peanut-\xadallergic individuals were signifi- cantly more likely to be of the IgG1 sub-\xadisotype (85.7% of IGHG cells; Fig. 5B) compared with DT-\xadbinding IgG1+ B cells from peanut-\xadallergic (55.1% of IGHG+ cells, P = 0.0015 by chi-\xadsquare test) or from non-\xadallergic individuals (52% of IGHG+ cells, P = 0.006 by chi-\xadsquare test).',
#   'These results show that Ara h 2– binding IgG+ B cells from peanut-\xadallergic individuals have defining characteristics of type 2–marked IgG+ cells from cluster 5: high SHM, predominant IgG1 constant regions, and transcription of FCER2/CD23 as well as IGHE.',
#   'Among Ara h 2–binding IgG+ cells, we identified a group of conver- gent sequences composed of three IgG1+ B cells (P4EC10, P4AC5, and P6EC2) using ambiguously IGHV3-\xad30*18 or IGHV3-\xad30-\xad5*01 paired with IGHJ6*02, as well as IGKV3-\xad20*01 and either IGKJ2*01 or IGKJ2*03 (data file S3).',
#   'In ELISA and biolayer inter- ferometry assays, we found that these antibodies bound with high affinity to Ara h 2',
#   'We identified three additional se- quence families containing at least two Ara h 2–binding cells each, although these families did not span across multiple individuals.',
#   'We found that all identified members of the 4C5G1 convergent family bound to the same Ara h 2 epitope (Ara h 2.008; fig. S13B).',
#   'To summarize, we found that B cell clones that bind the main allergen Ara h 2 with high affinity were predominantly somatically mutated, type 2–marked IgG1 memory cells that transcribed germ- line IGHE, contained convergent BCR sequences, and shared epitope recognition with IgE antibodies.',
#   'DISCUSSION Using single-\xadcell transcriptomics and functional analysis, we identified a population of somatically mutated IgG+ memory B cells character- ized by expression of IL-\xad4– and IL-\xad13–regulated genes, CD23/ A Isotype IGHG1 IGHG2 IGHG3 IGHG4 B C SHM frequency Ara h 2 DT DT Ara h 2 DT DT Non- allergic Peanut-allergic 0.00 0.25 0.50 0.75 1.00 Proportion of IGHG B cells Ara h 2 DT DT P = 0.0044 P < 0.0001 P = 0.0305 IGHG IGHM 0.0 0.1 0.2 Relative expression ACTB P = 0.0028 FCER2 GLT-IGHE total-IGHE 1.2 1.0 0.8 0.6 0.4 0.2 0.0 1.0 0.8 0.6 0.4 0.2 0.0 1.0 0.8 0.6 0.4 0.2 0.0 DT DT Ara h 2 Non- allergic PsIgE>100 DT DT Ara h 2 Non- allergic PsIgE>100 DT DT Ara h 2 Non- allergic PsIgE>100 P = 0.0150 P = 0.0021 P < 0.0001 P = 0.0001 P < 0.0001 Non- allergic Peanut-allergic Non- allergic Peanut-allergic Fig.',
#   'We found that the highly sensitized peanut-\xadallergic children had a much higher frequency of Ara h 2– binding IgG1+ memory B cells than children with low concentrations of PsIgE, again suggesting a relationship between peanut-\xadspecific IgG1+ memory cells and PsIgE antibodies.',
#   'Peanut-\xadallergic children with high concentrations of PsIgE (higher than 100 kUA/liter), low concentrations of PsIgE (lower than 5 kUA/liter), or intermediate concentrations of PsIgE (between 5 to 100 kUA/liter) were recruited among the pediatric population attending the Food Allergy clinic at Mount Sinai Hospitals.',
#   'Among 58 pediatric patients with peanut allergy, 18 patients had PsIgE higher than 100 kUA/liter, (PsIgE>100), 16 patients had sIgE lower than 5 kUA/liter (PsIgE<5), and 24 patients had sIgE between 8.0 and 76.6 kUA/liter (5 < PsIgE<100).',
#   'In terms of incidence of other atopic diseases, 89% of peanut-\xadallergic children with PsIgE>100 and 69% of peanut-\xadallergic children with PsIgE<5 reported a history of AD or asthma, which was not significantly different between the two groups (P = 0.147; table S1).',
#   'In our consensus sequences, however, SHM frequencies of paired heavy and light chains were closely correlated (linear regression slope P < 2 × 10−16, R2 = 0.63).'])

# %%
for ind, sent in enumerate(doc.sents):
    sent_text = re.sub(r'\s+', ' ', sent.text.strip().replace("\n", " "))
    print(f"{ind}: {sent_text}")
